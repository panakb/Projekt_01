# %% [markdown]
# <a href="https://colab.research.google.com/github/panakb/Projekt_01/blob/main/kampan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

data = pd.read_csv('train.csv')

# %%
data
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
data.describe(include='all')
# Out:
#                  age          job  marital  education default        balance  \
# count   45211.000000        45211    45211      45211   45211   45211.000000
# unique           NaN           12        3          4       2            NaN
# top              NaN  blue-collar  married  secondary      no            NaN
# freq             NaN         9732    27214      23202   44396            NaN
# mean       40.936210          NaN      NaN        NaN     NaN    1362.272058
# std        10.618762          NaN      NaN        NaN     NaN    3044.765829
# min        18.000000          NaN      NaN        NaN     NaN   -8019.000000
# 25%        33.000000          NaN      NaN        NaN     NaN      72.000000
# 50%        39.000000          NaN      NaN        NaN     NaN     448.000000
# 75%        48.000000          NaN      NaN        NaN     NaN    1428.000000
# max        95.000000          NaN      NaN        NaN     NaN  102127.000000
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# # **Seznam sloupců**
#
# age - ok, nechat jak je.
#
# job - vyhodit hodnoty unknown
#
# martial - label enocoder - 1, 2,3
#
# education - laber encoder a unknown nahradit secondary
#
# housing, loan - yes/ no nechat na 0 a 1
#
# contact - nechat zatím 0, 1, 2 - zvážit korelaci
#
# day a month - den vyhodit, nechat měsíc - graf před zprac, histogram atd.
#
# duration -  délka trvání hovoru - dáme do grafu a rozhodneme outlayers
#
# campaign - řešit outlayers
#
# pdays - nechat jak je
#
# poutcome - nechat jak je
#
#
#
# ***y - výsledek - yes / no nechat***

# %%
data.poutcome.unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
data[(data.pdays != -1) & (data.poutcome == 'unknown')].count()
# Out:
# age          5
# job          5
# marital      5
# education    5
# default      5
# balance      5
# housing      5
# loan         5
# contact      5
# day          5
# month        5
# duration     5
# campaign     5
# pdays        5
# previous     5
# poutcome     5
# y            5
# dtype: int64

# %%
data[data['education'] == 'unknown'].count()
# Out:
# age          1857
# job          1857
# marital      1857
# education    1857
# default      1857
# balance      1857
# housing      1857
# loan         1857
# contact      1857
# day          1857
# month        1857
# duration     1857
# campaign     1857
# pdays        1857
# previous     1857
# poutcome     1857
# y            1857
# dtype: int64

# %%
data_mod = data[data['job'] != 'unknown']

# %%
data_mod.education[data_mod.education == 'unknown'] = 'secondary'
# Out:
# <ipython-input-40-ab82ca84db76>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_mod.education[data_mod.education == 'unknown'] = 'secondary'
# <ipython-input-40-ab82ca84db76>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_mod.education[data_mod.education == 'unknown'] = 'secondary'

# %%
data_mod.education.unique()
# Out:
# array(['tertiary', 'secondary', 'primary'], dtype=object)

# %%
L = LabelEncoder()

data_mod = data_mod.apply(L.fit_transform)

data_mod.sample(5)
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 30049   12    4        1          2        0     1283        0     0        0
# 16745   21    1        1          1        0     1250        1     0        1
# 26669   14    9        1          1        0     5381        1     1        0
# 10104   35    0        2          1        0      632        0     1        2
# 44938   29    3        2          2        0     3986        0     0        1
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 30049    3      3       170         1      0         0         3  0
# 16745   23      5       575         3      0         0         3  0
# 26669   19      9       330         2      0         0         3  0
# 10104   10      6       328         0      0         0         3  0
# 44938    5     10       541         0    201         3         0  0

# %%
data_mod.default.unique()
# Out:
# array([0, 1])

# %%
data[data['default'] == 'yes']
# Out:
#        age           job   marital  education default  balance housing loan  \
# 7       42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 79      55      services  divorced  secondary     yes        1     yes   no
# 338     51        admin.    single  secondary     yes       -2      no   no
# 419     33    technician   married  secondary     yes       72     yes   no
# 458     33   blue-collar    single  secondary     yes      -60      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 41562   71       retired  divorced   tertiary     yes     1236     yes   no
# 44099   28    management    single   tertiary     yes     1414     yes   no
# 44161   25    technician    single   tertiary     yes      160      no  yes
# 44302   31      services    single  secondary     yes     -248      no   no
# 44606   27       student    single    primary     yes       25      no   no
#
# ...

# %%
data[(data.pdays != -1) & (data.poutcome == 'unknown')].count()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21808\699894551.py in ?()
# ----> 1 data[data.pdays != -1 and data.poutcome == 'unknown'].count()
#
# c:\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data['job'].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
data['pdays'].unique()
# Out:
# array([ -1, 151, 166,  91,  86, 143, 147,  89, 140, 176, 101, 174, 170,
#        167, 195, 165, 129, 188, 196, 172, 118, 119, 104, 171, 117, 164,
#        132, 131, 123, 159, 186, 111, 115, 116, 173, 178, 110, 152,  96,
#        103, 150, 175, 193, 181, 185, 154, 145, 138, 126, 180, 109, 158,
#        168,  97, 182, 127, 130, 194, 125, 105, 102,  26, 179,  28, 183,
#        155, 112, 120, 137, 124, 187, 190, 113, 162, 134, 169, 189,   8,
#        144, 191, 184, 177,   5,  99, 133,  93,  92,  10, 100, 156, 198,
#        106, 153, 146, 128,   7, 121, 160, 107,  90,  27, 197, 136, 139,
#        122, 157, 149, 135,  30, 114,  98, 192, 163,  34,  95, 141,  31,
#        199,  94, 108,  29, 268, 247, 253, 226, 244, 239, 245, 204, 231,
#        238, 258, 230, 254, 265,  71, 223, 246, 250, 266, 240, 205, 261,
#        259, 241, 260, 234, 251, 225, 161, 237, 262, 248, 255, 220, 227,
#        206, 224, 249, 235, 228, 263,   2, 270, 232, 252, 207, 200, 269,
# ...
